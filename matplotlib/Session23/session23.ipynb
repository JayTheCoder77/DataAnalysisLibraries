# %% [markdown]
# <a href="https://colab.research.google.com/github/JayTheCoder77/DataAnalysisLibraries/blob/main/matplotlib/Session23/session23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data **Visualization**
# **Types of data**
#
# 1.   Numerical Data
# 2.   Categorical Data

# %%
# import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2d plot
# bivariate analysis
# categorical -> numerical and numerical -> numerical
# use case -> time series data

# %%
# plotting a simple function
price = [48000,54000,57000,49000,47000,45000]
years = [2015,2016,2017,2018,2019,2020]
plt.plot(years , price)

# %%
# from a pandas datframe
batsman = pd.read_csv('sharma-kohli.csv')
batsman
plt.plot(batsman['index'],batsman['V Kohli'])

# %%
# mutiple plots
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])
# labels title
plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('Ipl Seasons')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
#  colors (hex) and line ( width and height )
# mutiple plots
plt.plot(batsman['index'],batsman['V Kohli'] ,color='green')
plt.plot(batsman['index'],batsman['RG Sharma'],color='#ef6b1d')
# labels title
plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('Ipl Seasons')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
# line style
#  colors (hex) and line ( width and height )
# mutiple plots
# plt.plot(batsman['index'],batsman['V Kohli'] ,color='green',linestyle='dashed')
# plt.plot(batsman['index'],batsman['V Kohli'] ,color='green',linestyle='dashdot')
plt.plot(batsman['index'],batsman['V Kohli'] ,color='green',linestyle='solid',linewidth=3,marker='D',markersize=10)
plt.plot(batsman['index'],batsman['RG Sharma'],color='#ef6b1d',linestyle='dotted',linewidth=2,marker='+')
# labels title
plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('Ipl Seasons')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
# legend -> location
plt.plot(batsman['index'],batsman['V Kohli'] ,color='green',label='VIRAT')
plt.plot(batsman['index'],batsman['RG Sharma'],color='#ef6b1d',label='ROHIT')

plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('Ipl Seasons')
plt.ylabel('Runs Scored')

plt.legend(loc='upper right')

# %%
# limiting axes
price = [48000,54000,57000,49000,47000,45000,4500000]
years = [2015,2016,2017,2018,2019,2020,2021]
plt.plot(years , price)
# graph has outlier

plt.ylim(0,175000)
plt.xlim(2017,2019)
# Out:
# (2017.0, 2019.0)

# %%
# grid

plt.plot(batsman['index'],batsman['V Kohli'] ,color='green')
plt.plot(batsman['index'],batsman['RG Sharma'],color='#ef6b1d')
# labels title
plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('Ipl Seasons')
plt.ylabel('Runs Scored')

plt.grid()

# %%
# show
plt.plot(batsman['index'],batsman['V Kohli'] ,color='green')
plt.plot(batsman['index'],batsman['RG Sharma'],color='#ef6b1d')
# labels title
plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('Ipl Seasons')
plt.ylabel('Runs Scored')

plt.show()

# %% [markdown]
# > SCATTER PLOTS

# %%
# plt.scatter simple function
x = np.linspace(-10,10,50)
y = 10*x + 3 + np.random.randint(0,300,50)
y
# Out:
# array([ 55.        , 126.08163265, 191.16326531, -80.75510204,
#        102.32653061,  89.40816327,  71.48979592, 171.57142857,
#        163.65306122, 222.73469388, 102.81632653,  21.89795918,
#        168.97959184, 203.06122449,  80.14285714,  92.2244898 ,
#         31.30612245,  97.3877551 , 187.46938776,   9.55102041,
#          8.63265306, 150.71428571, 103.79591837, 196.87755102,
#         72.95918367, 114.04081633, 281.12244898, 103.20408163,
#        109.28571429, 210.36734694,  66.44897959, 115.53061224,
#        290.6122449 , 125.69387755, 313.7755102 , 115.85714286,
#        334.93877551, 144.02040816, 109.10204082, 224.18367347,
#        197.26530612, 322.34693878,  84.42857143, 303.51020408,
#        339.59183673, 311.67346939, 236.75510204, 192.83673469,
#        232.91836735, 309.        ])

# %%
plt.scatter(x,y)

# %%
# plt scatter on pandas data
df = pd.read_csv('batter.csv')
df = df.head(50)

# %%
plt.scatter(df['avg'],df['strike_rate'],color='red',marker='+')
plt.title('avg and strike rate')
plt.xlabel('avg ')
plt.ylabel('strike rate')
# Out:
# Text(0, 0.5, 'strike rate')

# %%
# size
tips = sns.load_dataset('tips')
tips
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size']*20)

# %%
# scatterploy using plt.plot
# faster technique
plt.plot(tips['total_bill'],tips['tip'],'o')

# %% [markdown]
# **BAR CHART**

# %%
# simple bar chart
children = [30,50,20,10,5]
colors = ['blue','green','red','yellow','pink']
# plt.bar(colors,children,color='black')
plt.bar(colors,children,color=['blue','green','red','yellow','pink'])
# Out:
# <BarContainer object of 5 artists>

# %%
# horizontal bar chart
plt.barh(colors,children,color=['blue','green','red','yellow','pink'])
# Out:
# <BarContainer object of 5 artists>

# %%
# color and label
df = pd.read_csv('batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308
